# %% [markdown]
# What is the difference between hardware and software? Give one example of each.

# %% [markdown]
# Hardware: Refers to the physical, tangible components of a computer system. If you can touch it, it’s hardware. It provides the "body" and the raw processing power.
# Software: Refers to the set of digital instructions, programs, and data that tell the hardware exactly what to do. It is intangible and provides the "intelligence."
